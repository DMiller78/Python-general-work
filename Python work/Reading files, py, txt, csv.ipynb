# %%
f = open("/Users/mille/Desktop/gradcone.txt", "r") #opens file with name of "test.txt"

print(f.read(1))
print(f.read())
# Out:
# "
# Date	Lat	Long	Elevation_m	Dominant_conifer	Elevation_ft	Location"
# "7/22/2012	39.41777778	-105.7516667	3041.904	Lodge polepine	9980	""Kenosha Pass"	" CO"""
# "7/22/2012	39.41628056	-105.7519444	3053.1816	Aspen	10017	""Kenosha Pass"	" CO"""
# "7/22/2012	39.41696667	-105.7511111	3037.9416	Englanman spruce	9967	""Kenosha Pass"	" CO"""
# "7/22/2012	38.28822222	-106.0402778	2773.3752	Douglas fir	9099	Rio Grande National Forest"
# "7/22/2012	38.28747222	-106.0330556	2718.816	Douglas fir	8920	Rio Grande National Forest"
# "7/23/2012	37.55888889	-106.7127778	2696.2608	Blue spruce	8846	South Fork HWY 160"
# "7/23/2012	37.49122222	-106.7997222	3582.0096	Englanman spruce	11752	Lobo Lookout"
# "7/23/2012	37.44130556	-106.8786111	2461.5648	White Fir	8076	Wolf Creek Pass"
# "7/23/2012	37.44513889	-106.8861111	2396.9472	Douglas fir	7864	Below Wolf Creek Pass"
# "7/24/2012	37.592	-108.135	2455.4688	Blue spruce	8056	Doroles River San Juan National Forest"
# ...

# %%
f = open("/Users/mille/Desktop/DictChallenge2.py", "r")

print(f.read(1))
print(f.read())
# Out:
# l
# ocations = {0: "You are sitting in front of a computer learning Python",
#              1: "You are sitting at the end of a road before a small brick building",
#              2: "You are at the top of a hill",
#              3: "You are inside a building, a well house for a small stream",
#              4: "You are in a valley beside a stream",
#              5: "You are in the forest"}
#
# exits = {0: {"Q": 0},
#          1: {"W": 2, "E": 3, "N": 5, "S": 4, "Q": 0},
#          2: {"N": 5, "Q": 0},
#          3: {"W": 1, "Q": 0},
#          4: {"N": 1, "W": 2, "Q": 0},
#          5: {"W": 2, "S": 1, "Q": 0}}
#
# nameExits = {1: {"2": 2, "3": 3, "5": 5, "4": 4},
#              2: {"5": 5},
#              3: {"1": 1},
#              4: {"1": 1, "2": 2},
#              5: {"2": 2, "1": 1}}
#
# vocabulary = {"QUIT":  "Q",
#                "NORTH":  "N",
#                "SOUTH":  "S",
#                "EAST":  "E",
#                "WEST": "W",
#                "ROAD": "1",
# ...

# %%
f = open("/Users/mille/Desktop/gradcone1.csv", "r")
print(f.read(1))
print(f.read())
# Out:
# D
# ate  ,Latitude,Longitude,Elevation_m,Dominant_conifer,Elevation_ft,Location
# 7/22/2012,39.41777778,-105.7516667,3041.904,Lodge polepine,9980,"Kenosha Pass, CO"
# 7/22/2012,39.41628056,-105.7519444,3053.1816,Aspen,10017,"Kenosha Pass, CO"
# 7/22/2012,39.41696667,-105.7511111,3037.9416,Englanman spruce,9967,"Kenosha Pass, CO"
# 7/22/2012,38.28822222,-106.0402778,2773.3752,Douglas fir,9099,"Rio Grande National Forest, CO"
# 7/22/2012,38.28747222,-106.0330556,2718.816,Douglas fir,8920,"Rio Grande National Forest, CO"
# 7/23/2012,37.55888889,-106.7127778,2696.2608,Blue spruce,8846,South Fork HWY 1
# 7/23/2012,37.49122222,-106.7997222,3582.0096,Englanman spruce,11752,Lobo Looko
# 7/23/2012,37.44130556,-106.8786111,2461.5648,White Fir,8076,"Wolf Creek Pass, CO"
# 7/23/2012,37.44513889,-106.8861111,2396.9472,Douglas fir,7864,"Below Wolf Creek Pass, CO"
# 7/24/2012,37.592,-108.135,2455.4688,Blue spruce,8056,Doroles River San Juan National Forest
# ...

# %%
f = open("/Users/mille/Desktop/KingSoopers.txt", "r") #opens file with name of "test.txt"

print(f.read(1))
print(f.read())
# Out:
# ï
# »¿NAME:
#
#
# 45-50 MINUTES TO FINISH THIS ASSIGNMENT â€“ DO NOT WASTE TIME!!!
#
#
# REMINDER: WE ARE GUESTS DOING SCHOOL WORK IN KING SOOPERS. PLEASE ACT APPRIOATE AND REPRESENT THE SCHOLARS AT Omar D Blair.
#
#
# MAKE SURE YOU SHOW YOUâ€™RE WORK TO GET FULL CREDIT!
#
#
# Find the unit prices for the following:
# 1. Kroger Fruit & frosted Oâ€™s cereal 12.2 oz box for __________________
#
#
# 1. Kroger Fruits Rings cereal 28 oz bag for ______________________
#
#
# 1. Aquafina Purified Drinking water 24 pack/16.9 oz each___________
#
#
# 1. King Soopers Purified Drinking water 24 pack/16.9 oz each___________
#
#
# 1. Hines Ketchup 64 oz bottle _________________________
#
#
# 1. Hines Ketchup 16 oz bottle _________________________
#
#
# 1. 80% Ground Beef (price and unit price) ______________________
#
#
# 1. 90% Ground Beef (price and unit price) _______________________
#
#
#
#
# Compare unit prices:
#
#
# ...
